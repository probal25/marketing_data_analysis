# %% [markdown]
# ### Important Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(color_codes = True)
sns.set(rc={'figure.figsize': (13,10.1)})
pd.options.display.float_format = "{:.3f}".format
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### Loading Dataset

# %%
data_set = pd.read_excel('../data/marketing_campaign.xlsx', index_col = 0)
data_set.head()
# Out:
#       Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.000        0         0
# 2174        1954  Graduation         Single 46344.000        1         1
# 4141        1965  Graduation       Together 71613.000        0         0
# 6182        1984  Graduation       Together 26646.000        1         0
# 5324        1981         PhD        Married 58293.000        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...                  7
# 2174  2014-03-08       38        11          1  ...                  5
# 4141  2013-08-21       26       426         49  ...                  4
# 6182  2014-02-10       26        11          4  ...                  6
# 5324  2014-01-19       94       173         43  ...                  5
#
# ...

# %% [markdown]
# ### Dealing with duplicate values

# %%
# How many Duplicate rows are here??

dup_rows= data_set[data_set.duplicated()]
print(dup_rows.shape)
# Out:
# (182, 28)

# %%
# Dropping Duplicates

data_set = data_set.drop_duplicates()
print(data_set[data_set.duplicated()].shape)
# Out:
# (0, 28)

# %%
# Columns

print(data_set.columns)
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %% [markdown]
# ### Dealing with missing values

# %% [markdown]
# ##### Checking for missing values

# %%
# Missing value percentage
data_set.isna().sum()/len(data_set)
# Out:
# Year_Birth            0.000
# Education             0.000
# Marital_Status        0.000
# Income                0.012
# Kidhome               0.000
# Teenhome              0.000
# Dt_Customer           0.000
# Recency               0.000
# MntWines              0.000
# MntFruits             0.000
# MntMeatProducts       0.000
# MntFishProducts       0.000
# MntSweetProducts      0.000
# MntGoldProds          0.000
# NumDealsPurchases     0.000
# NumWebPurchases       0.000
# NumCatalogPurchases   0.000
# NumStorePurchases     0.000
# NumWebVisitsMonth     0.000
# AcceptedCmp3          0.000
# AcceptedCmp4          0.000
# AcceptedCmp5          0.000
# AcceptedCmp1          0.000
# AcceptedCmp2          0.000
# Complain              0.000
# Z_CostContact         0.000
# Z_Revenue             0.000
# Response              0.000
# dtype: float64

# %%
# Missing value Datas

data_set[data_set['Income'].isna()]
# Out:
#        Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# ID
# 1994         1983  Graduation        Married     nan        1         0
# 5255         1986  Graduation         Single     nan        1         0
# 7281         1959         PhD         Single     nan        0         0
# 7244         1951  Graduation         Single     nan        2         1
# 8557         1982  Graduation         Single     nan        1         0
# 10629        1973    2n Cycle        Married     nan        1         0
# 8996         1957         PhD        Married     nan        2         1
# 9235         1957  Graduation         Single     nan        1         1
# 5798         1973      Master       Together     nan        0         0
# 8268         1961         PhD        Married     nan        0         1
# 1295         1963  Graduation        Married     nan        0         1
# 2437         1989  Graduation        Married     nan        0         0
# ...

# %% [markdown]
# ##### Replacing missing values

# %%
# Theoretically, 25% to 30% is the maximum missing values are allowed
# This just contains only 1% missing value
# But i will replace those missing values with grouped data values[MEAN] of Income column

# %%
df = data_set.copy()
df.head()
# Out:
#       Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.000        0         0
# 2174        1954  Graduation         Single 46344.000        1         1
# 4141        1965  Graduation       Together 71613.000        0         0
# 6182        1984  Graduation       Together 26646.000        1         0
# 5324        1981         PhD        Married 58293.000        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...                  7
# 2174  2014-03-08       38        11          1  ...                  5
# 4141  2013-08-21       26       426         49  ...                  4
# 6182  2014-02-10       26        11          4  ...                  6
# 5324  2014-01-19       94       173         43  ...                  5
#
# ...

# %%
df['Income'].isna().sum()
# Out:
# 24

# %%
# Filling null values with grouped Mean

df['Income'] = df.groupby('Education')['Income'].transform(lambda group : group.fillna(np.mean(group)))

# %%
df['Income'].isna().sum()
# Out:
# 0

# %%
# No missing values

# %% [markdown]
# #### Clearing up some columns for analysis

# %%
# Creating new columns based on existing columns

df['Age'] = 2014 - df['Year_Birth']
df['Child_in_home'] = df['Kidhome'] + df['Teenhome']
df['Camp_accepted'] = df['AcceptedCmp3'] + df['AcceptedCmp4'] + df['AcceptedCmp5'] + df['AcceptedCmp1'] + df['AcceptedCmp2']
df['Item Purchased'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# %%
# Dropping unnecessery columns

df.drop(['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1','AcceptedCmp2', 'Kidhome', 'Teenhome', 'MntWines', 'MntFruits','MntMeatProducts', 'MntFishProducts', 'MntSweetProducts','MntGoldProds','Year_Birth'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Age', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased'],
#       dtype='object')

# %%
# Some more column clearing
# Minimizing variability
df['Marital_Status'].replace({'Divorced':'Alone','Single':'Alone','Married':'In couple','Together':'In couple','Absurd':'Alone','Widow':'Alone','YOLO':'Alone'}, inplace = True)

# %%
df.head()
# Out:
#        Education Marital_Status    Income Dt_Customer  Recency  \
# ID
# 5524  Graduation          Alone 58138.000  2012-09-04       58
# 2174  Graduation          Alone 46344.000  2014-03-08       38
# 4141  Graduation      In couple 71613.000  2013-08-21       26
# 6182  Graduation      In couple 26646.000  2014-02-10       26
# 5324         PhD      In couple 58293.000  2014-01-19       94
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 5524                  3                8                   10
# 2174                  2                1                    1
# 4141                  1                8                    2
# 6182                  2                2                    0
# 5324                  5                5                    3
#
#       NumStorePurchases  NumWebVisitsMonth  Complain  Z_CostContact  \
# ID
# 5524                  4                  7         0              3
# ...

# %% [markdown]
# ### Analysis

# %%
df.describe()
# Out:
#           Income  Recency  NumDealsPurchases  NumWebPurchases  \
# count   2058.000 2058.000           2058.000         2058.000
# mean   52364.699   48.952              2.339            4.099
# std    25378.943   28.999              1.943            2.798
# min     1730.000    0.000              0.000            0.000
# 25%    35701.750   24.000              1.000            2.000
# 50%    51912.000   49.000              2.000            4.000
# 75%    68242.500   74.000              3.000            6.000
# max   666666.000   99.000             15.000           27.000
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# count             2058.000           2058.000           2058.000  2058.000
# mean                 2.661              5.771              5.320     0.010
# std                  2.934              3.239              2.440     0.098
# min                  0.000              0.000              0.000     0.000
# ...

# %%
# I will start with the Box plot to see any outlires

# %%
sns.boxplot(x = "Income", data = df)

# %%
sns.boxplot(x = "Age", data = df)

# %%
sns.boxplot(x = "Item Purchased", data = df)

# %% [markdown]
# ##### Handling Outlires

# %%
# First we will find the Inter-Quantile Range (IQR) of my Dataset

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Income                32540.750
# Recency                  50.000
# NumDealsPurchases         2.000
# NumWebPurchases           4.000
# NumCatalogPurchases       4.000
# NumStorePurchases         5.000
# NumWebVisitsMonth         4.000
# Complain                  0.000
# Z_CostContact             0.000
# Z_Revenue                 0.000
# Response                  0.000
# Age                      18.000
# Child_in_home             1.000
# Camp_accepted             0.000
# Item Purchased          977.500
# dtype: float64

# %%
# Shape of the current Dataset
df.shape
# Out:
# (2058, 18)

# %%
# Removing outlires

df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Shape of the Dataset after removing outlires

df.shape
# Out:
# (1361, 18)

# %%
# We will check again with the Box plot

sns.boxplot(x = "Income", data = df)

# %%
sns.boxplot(x = "Age", data = df)

# %% [markdown]
# ### Further analysis

# %% [markdown]
# ###### Distributions

# %%
sns.countplot(data = df, x = "Age")

# %%
sns.histplot(data = df, x = "Age", kde = True, bins = 50)

# %%
sns.histplot(data = df, x = "Income",  hue="Education", element="step")

# %%
sns.histplot(data = df, x = "Education", kde = True)

# %%
sns.countplot(data = df, x = "Marital_Status")

# %%
sns.countplot(data = df, x = "Child_in_home")

# %%
sns.histplot(data = df, x = "Recency", bins = 30, kde = True)

# %%
sns.histplot(data = df, x = "Item Purchased", kde = True)

# %% [markdown]
# ##### Relationshps

# %%
# Between Marital Status and Item Purchased 

sns.barplot(x = "Marital_Status", y = "Item Purchased", data = df, ci = None)

# %%
sns.lineplot(data=df, x="Marital_Status", y="Item Purchased", ci = None)

# %%
# Between Children in home and Item Purchased 

sns.barplot(data=df, x="Child_in_home", y="Item Purchased", ci = None)

# %%
sns.lineplot(data=df, x="Child_in_home", y="Item Purchased", ci =None)

# %%
# Between Age and Item Purchased 

sns.barplot(data=df, x="Age", y="Item Purchased", ci=None)

# %%
sns.lineplot(data=df, x="Age", y="Item Purchased", ci=None)

# %%
# Website visit and website purchase

sns.barplot(data=df, x="NumWebVisitsMonth", y="NumWebPurchases" , ci=None)

# %%
sns.lineplot(data=df, x="NumWebVisitsMonth", y="NumWebPurchases" , ci=None)

# %%
# Age ad Recency [duration days of last visit]

sns.barplot(data= df , x= 'Age', y = 'Recency', ci = None)

# %%
sns.lineplot(data= df , x= 'Age', y = 'Recency', ci = None)

# %%
# Age and Website visit 

sns.barplot(data= df , x= 'Age', y = 'NumWebVisitsMonth', ci = None)

# %%
sns.barplot(data= df , x= 'Age', y = 'NumWebPurchases', ci = None)

# %%
# Education and website

sns.barplot(data= df , x= 'Education', y = 'NumWebVisitsMonth', ci = None)

# %%
sns.barplot(data= df , x= 'Education', y = 'NumWebPurchases', ci = None)

# %%
# Between Education and Item Purchased 

sns.barplot(x = "Education", y = "Item Purchased", data = df, ci = None)

# %%
sns.lineplot(x = "Education", y = "Item Purchased", data = df, ci = None)
