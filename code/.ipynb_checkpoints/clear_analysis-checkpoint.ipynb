# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(color_codes = True)
sns.set(rc={'figure.figsize': (10,6.1)})
pd.options.display.float_format = "{:.2f}".format

# %%
data_set = pd.read_excel('../data/marketing_campaign.xlsx', index_col = 0)
data_set.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.00        0         0
# 2174        1954  Graduation         Single 46344.00        1         1
# 4141        1965  Graduation       Together 71613.00        0         0
# 6182        1984  Graduation       Together 26646.00        1         0
# 5324        1981         PhD        Married 58293.00        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...                  7
# 2174  2014-03-08       38        11          1  ...                  5
# 4141  2013-08-21       26       426         49  ...                  4
# 6182  2014-02-10       26        11          4  ...                  6
# 5324  2014-01-19       94       173         43  ...                  5
#
#       AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ID
# 5524             0             0             0             0             0
# 2174             0             0             0             0             0
# 4141             0             0             0             0             0
# 6182             0             0             0             0             0
# 5324             0             0             0             0             0
#
#       Complain  Z_CostContact  Z_Revenue  Response
# ID
# 5524         0              3         11         1
# 2174         0              3         11         0
# 4141         0              3         11         0
# 6182         0              3         11         0
# 5324         0              3         11         0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Dealing with duplicate values

# %%
dup_rows= data_set[data_set.duplicated()]
print(dup_rows.shape)
# Out:
# (182, 28)

# %% [markdown]
# ###### dropping duplicate datas

# %%
data_set = data_set.drop_duplicates()
print(data_set[data_set.duplicated()].shape)
# Out:
# (0, 28)

# %%
data_set.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %% [markdown]
# #### Dealing with Missing values

# %% [markdown]
# ##### Missing value percentage

# %%
data_set.isna().sum()
# Out:
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
# Missing value Percentage

data_set['Income'].isna().sum()/len(data_set)
# Out:
# 0.011661807580174927

# %%
# Missing value dataset

data_set[data_set['Income'].isna()]
# Out:
#        Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# ID
# 1994         1983  Graduation        Married     nan        1         0
# 5255         1986  Graduation         Single     nan        1         0
# 7281         1959         PhD         Single     nan        0         0
# 7244         1951  Graduation         Single     nan        2         1
# 8557         1982  Graduation         Single     nan        1         0
# 10629        1973    2n Cycle        Married     nan        1         0
# 8996         1957         PhD        Married     nan        2         1
# 9235         1957  Graduation         Single     nan        1         1
# 5798         1973      Master       Together     nan        0         0
# 8268         1961         PhD        Married     nan        0         1
# 1295         1963  Graduation        Married     nan        0         1
# 2437         1989  Graduation        Married     nan        0         0
# 2863         1970  Graduation         Single     nan        1         2
# 10475        1970      Master       Together     nan        0         1
# 2902         1958  Graduation       Together     nan        1         1
# 4345         1964    2n Cycle         Single     nan        1         1
# 3769         1972         PhD       Together     nan        1         0
# 7187         1969      Master       Together     nan        1         1
# 1612         1981         PhD         Single     nan        1         0
# 5079         1971  Graduation        Married     nan        1         1
# 10339        1954      Master       Together     nan        0         1
# 3117         1955  Graduation         Single     nan        0         1
# 5250         1943      Master          Widow     nan        0         0
# 8720         1978    2n Cycle       Together     nan        0         0
#
#       Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                               ...
# 1994   2013-11-15       11         5          5  ...                  7
# 5255   2013-02-20       19         5          1  ...                  1
# 7281   2013-11-05       80        81         11  ...                  2
# 7244   2014-01-01       96        48          5  ...                  6
# 8557   2013-06-17       57        11          3  ...                  6
# 10629  2012-09-14       25        25          3  ...                  8
# 8996   2012-11-19        4       230         42  ...                  9
# 9235   2014-05-27       45         7          0  ...                  7
# 5798   2013-11-23       87       445         37  ...                  1
# 8268   2013-07-11       23       352          0  ...                  6
# 1295   2013-08-11       96       231         65  ...                  4
# 2437   2013-06-03       69       861        138  ...                  3
# 2863   2013-08-23       67       738         20  ...                  7
# 10475  2013-04-01       39       187          5  ...                  5
# 2902   2012-09-03       87        19          4  ...                  5
# 4345   2014-01-12       49         5          1  ...                  7
# 3769   2014-03-02       17        25          1  ...                  7
# 7187   2013-05-18       52       375         42  ...                  3
# 1612   2013-05-31       82        23          0  ...                  6
# 5079   2013-03-03       82        71          1  ...                  8
# 10339  2013-06-23       83       161          0  ...                  6
# 3117   2013-10-18       95       264          0  ...                  7
# 5250   2013-10-30       75       532        126  ...                  1
# 8720   2012-08-12       53        32          2  ...                  0
#
#        AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ID
# 1994              0             0             0             0             0
# 5255              0             0             0             0             0
# 7281              0             0             0             0             0
# 7244              0             0             0             0             0
# 8557              0             0             0             0             0
# 10629             0             0             0             0             0
# 8996              0             0             0             0             0
# 9235              0             0             0             0             0
# 5798              0             0             0             0             0
# 8268              0             0             0             0             0
# 1295              0             0             0             0             0
# 2437              0             1             0             1             0
# 2863              0             1             0             1             0
# 10475             0             0             0             0             0
# 2902              0             0             0             0             0
# 4345              0             0             0             0             0
# 3769              0             0             0             0             0
# 7187              0             0             0             0             0
# 1612              0             0             0             0             0
# 5079              0             0             0             0             0
# 10339             0             0             0             0             0
# 3117              0             0             0             0             0
# 5250              0             0             1             0             0
# 8720              0             1             0             0             0
#
#        Complain  Z_CostContact  Z_Revenue  Response
# ID
# 1994          0              3         11         0
# 5255          0              3         11         0
# 7281          0              3         11         0
# 7244          0              3         11         0
# 8557          0              3         11         0
# 10629         0              3         11         0
# 8996          0              3         11         0
# 9235          0              3         11         0
# 5798          0              3         11         0
# 8268          0              3         11         0
# 1295          0              3         11         0
# 2437          0              3         11         0
# 2863          0              3         11         0
# 10475         0              3         11         0
# 2902          0              3         11         0
# 4345          0              3         11         0
# 3769          0              3         11         0
# 7187          0              3         11         0
# 1612          0              3         11         0
# 5079          0              3         11         0
# 10339         0              3         11         0
# 3117          0              3         11         0
# 5250          0              3         11         1
# 8720          0              3         11         0
#
# [24 rows x 28 columns]

# %% [markdown]
# ###### Handling Missing values

# %%
df = data_set.copy()
df.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.00        0         0
# 2174        1954  Graduation         Single 46344.00        1         1
# 4141        1965  Graduation       Together 71613.00        0         0
# 6182        1984  Graduation       Together 26646.00        1         0
# 5324        1981         PhD        Married 58293.00        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...                  7
# 2174  2014-03-08       38        11          1  ...                  5
# 4141  2013-08-21       26       426         49  ...                  4
# 6182  2014-02-10       26        11          4  ...                  6
# 5324  2014-01-19       94       173         43  ...                  5
#
#       AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# ID
# 5524             0             0             0             0             0
# 2174             0             0             0             0             0
# 4141             0             0             0             0             0
# 6182             0             0             0             0             0
# 5324             0             0             0             0             0
#
#       Complain  Z_CostContact  Z_Revenue  Response
# ID
# 5524         0              3         11         1
# 2174         0              3         11         0
# 4141         0              3         11         0
# 6182         0              3         11         0
# 5324         0              3         11         0
#
# [5 rows x 28 columns]

# %% [markdown]
# ###### Filling null values with grouped Mean

# %%
df['Income'] = df.groupby('Education')['Income'].transform(lambda group : group.fillna(np.mean(group)))

# %%
df['Income'].isna().sum()
# Out:
# 0

# %% [markdown]
# ###### Clearing up Columns

# %%
df.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %%
df['Child_in_home'] = df['Kidhome'] + df['Teenhome']
df.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.00        0         0
# 2174        1954  Graduation         Single 46344.00        1         1
# 4141        1965  Graduation       Together 71613.00        0         0
# 6182        1984  Graduation       Together 26646.00        1         0
# 5324        1981         PhD        Married 58293.00        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp3  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...             0
# 2174  2014-03-08       38        11          1  ...             0
# 4141  2013-08-21       26       426         49  ...             0
# 6182  2014-02-10       26        11          4  ...             0
# 5324  2014-01-19       94       173         43  ...             0
#
#       AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# ID
# 5524             0             0             0             0         0
# 2174             0             0             0             0         0
# 4141             0             0             0             0         0
# 6182             0             0             0             0         0
# 5324             0             0             0             0         0
#
#       Z_CostContact  Z_Revenue  Response  Child_in_home
# ID
# 5524              3         11         1              0
# 2174              3         11         0              2
# 4141              3         11         0              0
# 6182              3         11         0              1
# 5324              3         11         0              1
#
# [5 rows x 29 columns]

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.00        0         0
# 2174        1954  Graduation         Single 46344.00        1         1
# 4141        1965  Graduation       Together 71613.00        0         0
# 6182        1984  Graduation       Together 26646.00        1         0
# 5324        1981         PhD        Married 58293.00        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp3  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...             0
# 2174  2014-03-08       38        11          1  ...             0
# 4141  2013-08-21       26       426         49  ...             0
# 6182  2014-02-10       26        11          4  ...             0
# 5324  2014-01-19       94       173         43  ...             0
#
#       AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  \
# ID
# 5524             0             0             0             0         0
# 2174             0             0             0             0         0
# 4141             0             0             0             0         0
# 6182             0             0             0             0         0
# 5324             0             0             0             0         0
#
#       Z_CostContact  Z_Revenue  Response  Child_in_home
# ID
# 5524              3         11         1              0
# 2174              3         11         0              2
# 4141              3         11         0              0
# 6182              3         11         0              1
# 5324              3         11         0              1
#
# [5 rows x 29 columns]

# %%
df_copy.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Child_in_home'],
#       dtype='object')

# %%
df_copy['Camp_accepted'] = df_copy['AcceptedCmp3'] + df_copy['AcceptedCmp4'] + df_copy['AcceptedCmp5'] + df_copy['AcceptedCmp1'] + df_copy['AcceptedCmp2']
df_copy.head()
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# ID
# 5524        1957  Graduation         Single 58138.00        0         0
# 2174        1954  Graduation         Single 46344.00        1         1
# 4141        1965  Graduation       Together 71613.00        0         0
# 6182        1984  Graduation       Together 26646.00        1         0
# 5324        1981         PhD        Married 58293.00        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp4  \
# ID                                              ...
# 5524  2012-09-04       58       635         88  ...             0
# 2174  2014-03-08       38        11          1  ...             0
# 4141  2013-08-21       26       426         49  ...             0
# 6182  2014-02-10       26        11          4  ...             0
# 5324  2014-01-19       94       173         43  ...             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  \
# ID
# 5524             0             0             0         0              3
# 2174             0             0             0         0              3
# 4141             0             0             0         0              3
# 6182             0             0             0         0              3
# 5324             0             0             0         0              3
#
#       Z_Revenue  Response  Child_in_home  Camp_accepted
# ID
# 5524         11         1              0              0
# 2174         11         0              2              0
# 4141         11         0              0              0
# 6182         11         0              1              0
# 5324         11         0              1              0
#
# [5 rows x 30 columns]

# %%
df_copy=df_copy.drop(['AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1','AcceptedCmp2', 'Kidhome', 'Teenhome'], axis = 1).copy()

# %%
df_copy.head()
# Out:
#       Year_Birth   Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 5524        1957  Graduation         Single 58138.00  2012-09-04       58
# 2174        1954  Graduation         Single 46344.00  2014-03-08       38
# 4141        1965  Graduation       Together 71613.00  2013-08-21       26
# 6182        1984  Graduation       Together 26646.00  2014-02-10       26
# 5324        1981         PhD        Married 58293.00  2014-01-19       94
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# ID                                                           ...
# 5524       635         88              546              172  ...
# 2174        11          1                6                2  ...
# 4141       426         49              127              111  ...
# 6182        11          4               20               10  ...
# 5324       173         43              118               46  ...
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ID
# 5524                8                   10                  4
# 2174                1                    1                  2
# 4141                8                    2                 10
# 6182                2                    0                  4
# 5324                5                    3                  6
#
#       NumWebVisitsMonth  Complain  Z_CostContact  Z_Revenue  Response  \
# ID
# 5524                  7         0              3         11         1
# 2174                  5         0              3         11         0
# 4141                  4         0              3         11         0
# 6182                  6         0              3         11         0
# 5324                  5         0              3         11         0
#
#       Child_in_home  Camp_accepted
# ID
# 5524              0              0
# 2174              2              0
# 4141              0              0
# 6182              1              0
# 5324              1              0
#
# [5 rows x 23 columns]

# %%
 df_copy['Item Purchased'] = df_copy['MntWines'] + df_copy['MntFruits'] + df_copy['MntMeatProducts'] + df_copy['MntFishProducts'] + df_copy['MntSweetProducts'] + df_copy['MntGoldProds']

# %%
df_copy = df_copy.drop(['MntWines', 'MntFruits','MntMeatProducts', 'MntFishProducts', 'MntSweetProducts','MntGoldProds'], axis = 1).copy()

# %%
df_copy.columns
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Dt_Customer',
#        'Recency', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'Child_in_home',
#        'Camp_accepted', 'Item Purchased'],
#       dtype='object')

# %%
df_copy['Age'] = 2014 - df_copy['Year_Birth']

# %%
df_copy = df_copy.drop(['Year_Birth'], axis = 1).copy()

# %%
df_copy.head()
# Out:
#        Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 5524  Graduation         Single 58138.00  2012-09-04       58
# 2174  Graduation         Single 46344.00  2014-03-08       38
# 4141  Graduation       Together 71613.00  2013-08-21       26
# 6182  Graduation       Together 26646.00  2014-02-10       26
# 5324         PhD        Married 58293.00  2014-01-19       94
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 5524                  3                8                   10
# 2174                  2                1                    1
# 4141                  1                8                    2
# 6182                  2                2                    0
# 5324                  5                5                    3
#
#       NumStorePurchases  NumWebVisitsMonth  Complain  Z_CostContact  \
# ID
# 5524                  4                  7         0              3
# 2174                  2                  5         0              3
# 4141                 10                  4         0              3
# 6182                  4                  6         0              3
# 5324                  6                  5         0              3
#
#       Z_Revenue  Response  Child_in_home  Camp_accepted  Item Purchased  Age
# ID
# 5524         11         1              0              0            1617   57
# 2174         11         0              2              0              27   60
# 4141         11         0              0              0             776   49
# 6182         11         0              1              0              53   30
# 5324         11         0              1              0             422   33

# %%
df_copy['Z_Revenue'].mean()
# Out:
# 11.0

# %%
df_copy.describe()
# Out:
#          Income  Recency  NumDealsPurchases  NumWebPurchases  \
# count   2058.00  2058.00            2058.00          2058.00
# mean   52364.70    48.95               2.34             4.10
# std    25378.94    29.00               1.94             2.80
# min     1730.00     0.00               0.00             0.00
# 25%    35701.75    24.00               1.00             2.00
# 50%    51912.00    49.00               2.00             4.00
# 75%    68242.50    74.00               3.00             6.00
# max   666666.00    99.00              15.00            27.00
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# count              2058.00            2058.00            2058.00   2058.00
# mean                  2.66               5.77               5.32      0.01
# std                   2.93               3.24               2.44      0.10
# min                   0.00               0.00               0.00      0.00
# 25%                   0.00               3.00               3.00      0.00
# 50%                   2.00               5.00               6.00      0.00
# 75%                   4.00               8.00               7.00      0.00
# max                  28.00              13.00              20.00      1.00
#
#        Z_CostContact  Z_Revenue  Response  Child_in_home  Camp_accepted  \
# count        2058.00    2058.00   2058.00        2058.00        2058.00
# mean            3.00      11.00      0.15           0.95           0.30
# std             0.00       0.00      0.36           0.75           0.68
# min             3.00      11.00      0.00           0.00           0.00
# 25%             3.00      11.00      0.00           0.00           0.00
# 50%             3.00      11.00      0.00           1.00           0.00
# 75%             3.00      11.00      0.00           1.00           0.00
# max             3.00      11.00      1.00           3.00           4.00
#
#        Item Purchased     Age
# count         2058.00 2058.00
# mean           606.24   45.21
# std            602.84   11.97
# min              5.00   18.00
# 25%             69.00   37.00
# 50%            396.50   44.00
# 75%           1046.50   55.00
# max           2525.00  121.00

# %%
df_copy['Marital_Situation']=df_copy['Marital_Status'].replace({'Divorced':'Alone','Single':'Alone','Married':'In couple','Together':'In couple','Absurd':'Alone','Widow':'Alone','YOLO':'Alone'}, inplace = True)

# %%
df_copy['Marital_Situation'].head()
# Out:
# ID
# 5524    None
# 2174    None
# 4141    None
# 6182    None
# 5324    None
# Name: Marital_Situation, dtype: object

# %%
df_copy.head()
# Out:
#        Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 5524  Graduation          Alone 58138.00  2012-09-04       58
# 2174  Graduation          Alone 46344.00  2014-03-08       38
# 4141  Graduation      In couple 71613.00  2013-08-21       26
# 6182  Graduation      In couple 26646.00  2014-02-10       26
# 5324         PhD      In couple 58293.00  2014-01-19       94
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 5524                  3                8                   10
# 2174                  2                1                    1
# 4141                  1                8                    2
# 6182                  2                2                    0
# 5324                  5                5                    3
#
#       NumStorePurchases  NumWebVisitsMonth  Complain  Z_CostContact  \
# ID
# 5524                  4                  7         0              3
# 2174                  2                  5         0              3
# 4141                 10                  4         0              3
# 6182                  4                  6         0              3
# 5324                  6                  5         0              3
#
#       Z_Revenue  Response  Child_in_home  Camp_accepted  Item Purchased  Age  \
# ID
# 5524         11         1              0              0            1617   57
# 2174         11         0              2              0              27   60
# 4141         11         0              0              0             776   49
# 6182         11         0              1              0              53   30
# 5324         11         0              1              0             422   33
#
#      Marital_Situation
# ID
# 5524              None
# 2174              None
# 4141              None
# 6182              None
# 5324              None

# %%
df_copy.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased', 'Age', 'Marital_Situation'],
#       dtype='object')

# %%
df_copy.drop(['Marital_Situation'], axis = 1, inplace = True)

# %%
df_copy.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased', 'Age'],
#       dtype='object')

# %%
df_copy.head()
# Out:
#        Education Marital_Status   Income Dt_Customer  Recency  \
# ID
# 5524  Graduation          Alone 58138.00  2012-09-04       58
# 2174  Graduation          Alone 46344.00  2014-03-08       38
# 4141  Graduation      In couple 71613.00  2013-08-21       26
# 6182  Graduation      In couple 26646.00  2014-02-10       26
# 5324         PhD      In couple 58293.00  2014-01-19       94
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ID
# 5524                  3                8                   10
# 2174                  2                1                    1
# 4141                  1                8                    2
# 6182                  2                2                    0
# 5324                  5                5                    3
#
#       NumStorePurchases  NumWebVisitsMonth  Complain  Z_CostContact  \
# ID
# 5524                  4                  7         0              3
# 2174                  2                  5         0              3
# 4141                 10                  4         0              3
# 6182                  4                  6         0              3
# 5324                  6                  5         0              3
#
#       Z_Revenue  Response  Child_in_home  Camp_accepted  Item Purchased  Age
# ID
# 5524         11         1              0              0            1617   57
# 2174         11         0              2              0              27   60
# 4141         11         0              0              0             776   49
# 6182         11         0              1              0              53   30
# 5324         11         0              1              0             422   33

# %%
df_copy.describe()
# Out:
#          Income  Recency  NumDealsPurchases  NumWebPurchases  \
# count   2058.00  2058.00            2058.00          2058.00
# mean   52364.70    48.95               2.34             4.10
# std    25378.94    29.00               1.94             2.80
# min     1730.00     0.00               0.00             0.00
# 25%    35701.75    24.00               1.00             2.00
# 50%    51912.00    49.00               2.00             4.00
# 75%    68242.50    74.00               3.00             6.00
# max   666666.00    99.00              15.00            27.00
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# count              2058.00            2058.00            2058.00   2058.00
# mean                  2.66               5.77               5.32      0.01
# std                   2.93               3.24               2.44      0.10
# min                   0.00               0.00               0.00      0.00
# 25%                   0.00               3.00               3.00      0.00
# 50%                   2.00               5.00               6.00      0.00
# 75%                   4.00               8.00               7.00      0.00
# max                  28.00              13.00              20.00      1.00
#
#        Z_CostContact  Z_Revenue  Response  Child_in_home  Camp_accepted  \
# count        2058.00    2058.00   2058.00        2058.00        2058.00
# mean            3.00      11.00      0.15           0.95           0.30
# std             0.00       0.00      0.36           0.75           0.68
# min             3.00      11.00      0.00           0.00           0.00
# 25%             3.00      11.00      0.00           0.00           0.00
# 50%             3.00      11.00      0.00           1.00           0.00
# 75%             3.00      11.00      0.00           1.00           0.00
# max             3.00      11.00      1.00           3.00           4.00
#
#        Item Purchased     Age
# count         2058.00 2058.00
# mean           606.24   45.21
# std            602.84   11.97
# min              5.00   18.00
# 25%             69.00   37.00
# 50%            396.50   44.00
# 75%           1046.50   55.00
# max           2525.00  121.00

# %% [markdown]
# ### Plotting

# %%
count_plot = sns.countplot(x = 'Marital_Status' , hue = 'Education', data = df_copy)
count_plot

# %%
bar_plot = sns.barplot(x = "Education", y = "Income", data = df_copy)

# %%
sns.set_theme(style="whitegrid")
bp = sns.boxplot(x = "Income", data = df_copy)
bp

# %%
bp = sns.boxplot(x = "Age", data = df_copy)
bp

# %%
bp = sns.boxplot(x = "Item Purchased", data = df_copy)
bp

# %% [markdown]
# #### Handling outlires

# %%
Q1 = df_copy.quantile(0.25)
Q3 = df_copy.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Income                32540.75
# Recency                  50.00
# NumDealsPurchases         2.00
# NumWebPurchases           4.00
# NumCatalogPurchases       4.00
# NumStorePurchases         5.00
# NumWebVisitsMonth         4.00
# Complain                  0.00
# Z_CostContact             0.00
# Z_Revenue                 0.00
# Response                  0.00
# Child_in_home             1.00
# Camp_accepted             0.00
# Item Purchased          977.50
# Age                      18.00
# dtype: float64

# %%
dfcopy = df_copy.copy()

# %%
dfcopy = dfcopy[~((dfcopy < (Q1 - 1.5 * IQR)) |(dfcopy > (Q3 + 1.5 * IQR))).any(axis=1)]
print(dfcopy.shape)
print(df_copy.shape)
# Out:
# (1361, 18)
# (2058, 18)

# %%
sns.set_theme(style="whitegrid")
bp = sns.boxplot(x = "Income", data = dfcopy)
bp

# %%
bp = sns.boxplot(x = "Age", data = dfcopy)
bp

# %%
bp = sns.boxplot(x = "Item Purchased", data = dfcopy)
bp

# %%
dfcopy.describe()
# Out:
#         Income  Recency  NumDealsPurchases  NumWebPurchases  \
# count  1361.00  1361.00            1361.00          1361.00
# mean  48002.46    50.70               2.14             3.66
# std   18939.68    28.68               1.33             2.48
# min    5305.00     0.00               0.00             0.00
# 25%   33168.00    26.00               1.00             2.00
# 50%   47025.00    51.00               2.00             3.00
# 75%   63381.00    76.00               3.00             5.00
# max   92859.00    99.00               6.00            11.00
#
#        NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# count              1361.00            1361.00            1361.00   1361.00
# mean                  2.04               5.53               5.34      0.00
# std                   2.38               3.16               2.19      0.00
# min                   0.00               0.00               0.00      0.00
# 25%                   0.00               3.00               4.00      0.00
# 50%                   1.00               4.00               6.00      0.00
# 75%                   3.00               8.00               7.00      0.00
# max                  10.00              13.00              13.00      0.00
#
#        Z_CostContact  Z_Revenue  Response  Child_in_home  Camp_accepted  \
# count        1361.00    1361.00   1361.00        1361.00        1361.00
# mean            3.00      11.00      0.00           0.99           0.00
# std             0.00       0.00      0.00           0.65           0.00
# min             3.00      11.00      0.00           0.00           0.00
# 25%             3.00      11.00      0.00           1.00           0.00
# 50%             3.00      11.00      0.00           1.00           0.00
# 75%             3.00      11.00      0.00           1.00           0.00
# max             3.00      11.00      0.00           2.00           0.00
#
#        Item Purchased     Age
# count         1361.00 1361.00
# mean           455.38   44.70
# std            494.04   11.46
# min              9.00   19.00
# 25%             55.00   36.00
# 50%            231.00   43.00
# 75%            801.00   54.00
# max           2440.00   74.00

# %%
bp = sns.barplot(x = "Marital_Status", y = "Item Purchased", data = dfcopy)

# %%
lp  = sns.lineplot(data=dfcopy, x="Age", y="Income")
lp

# %%
lp  = sns.lineplot(data=dfcopy, x="Education", y="Item Purchased", sort = False)
lp

# %%
lp  = sns.lineplot(data=dfcopy, x="Child_in_home", y="Item Purchased")
lp

# %%
hp = sns.histplot(data = dfcopy, x = "Age")

# %%
hp = sns.histplot(data = dfcopy, x = "Income",  hue="Education", element="step")

# %%
sns.barplot(data=dfcopy, x="Child_in_home", y="Item Purchased")

# %%
sns.histplot(data=dfcopy, x="Item Purchased", hue="Marital_Status", multiple="dodge", shrink=.8)

# %%
sns.relplot(x="Education", y = "Item Purchased", data=dfcopy)

# %%
dfcopy.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased', 'Age'],
#       dtype='object')

# %%
sns.lineplot(x='Age', y = 'Child_in_home' ,data = dfcopy)

# %%
lp  = sns.lineplot(data=dfcopy, x="Age", y="Item Purchased",markers=True, dashes=False)
lp

# %%
dfcopy.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased', 'Age'],
#       dtype='object')

# %%
sns.lineplot(x='Marital_Status', y = 'Income' ,data = dfcopy, ci = None)

# %%
hp = sns.histplot(data = dfcopy, x = "Education")

# %%
lp  = sns.lineplot(data=dfcopy, x="Age", y="Item Purchased", ci=None)
lp

# %%
lp  = sns.lineplot(data=dfcopy, x="Age", y="Complain")
lp

# %%
dfcopy.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Dt_Customer', 'Recency',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response', 'Child_in_home', 'Camp_accepted',
#        'Item Purchased', 'Age'],
#       dtype='object')

# %%
lp  = sns.lineplot(data=dfcopy, x="NumWebVisitsMonth", y="NumWebPurchases" , ci=None)
lp

# %%
sns.lineplot(x="NumWebVisitsMonth",y = "NumWebPurchases", data = dfcopy, ci = None)
